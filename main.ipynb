# %%
from mousehunt.lib import show_simulation, show_failure_rates
from datetime import datetime, timedelta

# %%
cheese_count = 157
curr_delay = timedelta(minutes=11)
curr_time = datetime.now()
offset = timedelta(minutes=0)
# offset = timedelta(minutes=15)

# %%
show_simulation(cheese_count, curr_time, curr_delay, offset)
# Out:
#     Calculating timings for:
#     curr_time           : 2025-05-26 14:54:32
#     next_hunt_time      : 2025-05-26 15:05:32
#     trap_check_time     : 2025-05-26 15:00:00
#     trap_check_offset   : 0:00:00
# shape: (11, 2)
# ┌────────────┬────────────────────────────┐
# │ statistic  ┆ times                      │
# │ ---        ┆ ---                        │
# │ str        ┆ str                        │
# ╞════════════╪════════════════════════════╡
# │ count      ┆ 1000                       │
# │ null_count ┆ 0                          │
# │ mean       ┆ 2025-05-28 01:41:26.434945 │
# │ std        ┆ null                       │
# │ min        ┆ 2025-05-28 01:01:58.618946 │
# │ 5%         ┆ 2025-05-28 01:23:04.618946 │
# │ 25%        ┆ 2025-05-28 01:33:25.618946 │
# │ 50%        ┆ 2025-05-28 01:42:08.618946 │
# │ 75%        ┆ 2025-05-28 01:49:45.618946 │
# │ 95%        ┆ 2025-05-28 02:00:00.618946 │
# │ max        ┆ 2025-05-28 02:07:30.618946 │
# ...

# %%
show_failure_rates()
# Out:
# alt.Chart(...)
