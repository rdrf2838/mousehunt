# %%
from mousehunt.lib import show_simulation, show_failure_rates
from datetime import datetime, timedelta

# %%
cheese_count = 8
curr_delay = timedelta(minutes=12)
curr_time = datetime.now()
offset = timedelta(minutes=0)
# offset = timedelta(minutes=15)

# %%
show_simulation(cheese_count, curr_time, curr_delay, offset)
# Out:
#     Calculating timings for:
#     curr_time           : 2025-06-15 07:47:45
#     next_hunt_time      : 2025-06-15 07:59:45
#     trap_check_time     : 2025-06-15 08:00:00
#     trap_check_offset   : 0:00:00
# shape: (11, 2)
# ┌────────────┬────────────────────────────┐
# │ statistic  ┆ times                      │
# │ ---        ┆ ---                        │
# │ str        ┆ str                        │
# ╞════════════╪════════════════════════════╡
# │ count      ┆ 1000                       │
# │ null_count ┆ 0                          │
# │ mean       ┆ 2025-06-15 09:25:34.840706 │
# │ std        ┆ null                       │
# │ min        ┆ 2025-06-15 09:18:50.223706 │
# │ 5%         ┆ 2025-06-15 09:21:37.223706 │
# │ 25%        ┆ 2025-06-15 09:24:00.223706 │
# │ 50%        ┆ 2025-06-15 09:25:30.223706 │
# │ 75%        ┆ 2025-06-15 09:27:14.223706 │
# │ 95%        ┆ 2025-06-15 09:29:26.223706 │
# │ max        ┆ 2025-06-15 09:32:42.223706 │
# └────────────┴────────────────────────────┘
# alt.Chart(...)

# %%
show_failure_rates()
# Out:
# alt.Chart(...)
