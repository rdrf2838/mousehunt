# %%
from mousehunt.lib import show_simulation
from datetime import datetime, timedelta

# %%
cheese_count = 9
curr_delay = timedelta(minutes=16)
curr_time = datetime.now()
offset = timedelta(minutes=0)

# %%
show_simulation(cheese_count, curr_time, curr_delay, offset)
# Out:
#     Calculating timings for:
#     curr_time           : 2025-05-26 14:14:15
#     next_hunt_time      : 2025-05-26 14:30:15
#     trap_check_time     : 2025-05-26 15:00:00
#     trap_check_offset   : 0:00:00
# shape: (11, 2)
# ┌────────────┬────────────────────────────┐
# │ statistic  ┆ times                      │
# │ ---        ┆ ---                        │
# │ str        ┆ str                        │
# ╞════════════╪════════════════════════════╡
# │ count      ┆ 1000                       │
# │ null_count ┆ 0                          │
# │ mean       ┆ 2025-05-26 16:13:12.809318 │
# │ std        ┆ null                       │
# │ min        ┆ 2025-05-26 16:04:32.857319 │
# │ 5%         ┆ 2025-05-26 16:08:41.857319 │
# │ 25%        ┆ 2025-05-26 16:11:20.857319 │
# │ 50%        ┆ 2025-05-26 16:13:13.857319 │
# │ 75%        ┆ 2025-05-26 16:15:02.857319 │
# │ 95%        ┆ 2025-05-26 16:17:33.857319 │
# │ max        ┆ 2025-05-26 16:21:06.857319 │
# ...
